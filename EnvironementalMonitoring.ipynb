# %% [markdown]
# <a href="https://colab.research.google.com/github/yonasyifter/IOT_EnvironmentalMonitoring/blob/main/EnvironementalMonitoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Environmental Monitoring Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
path = 'E:/AI'
# List all files in the downloaded directory
files_in_dataset = os.listdir(path)

# Filter for CSV files
csv_files = [f for f in files_in_dataset if f.endswith('.csv')]

if not csv_files:
    raise FileNotFoundError(f"No CSV files found in the dataset directory: {path}")

# Assuming the first CSV file found is the correct one for simplicity.
# If there are multiple CSVs and specific one is needed, further logic may be required.
first_csv_file = csv_files[0]
full_csv_path = os.path.join(path, first_csv_file)

df = pd.read_csv(full_csv_path)

print(f"Successfully loaded '{first_csv_file}'.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4049442888.py in <cell line: 0>()
#       2 path = 'E:/AI'
#       3 # List all files in the downloaded directory
# ----> 4 files_in_dataset = os.listdir(path)
#       5
#       6 # Filter for CSV files
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/AI'
